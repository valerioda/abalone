# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.integrate import quad
import scipy.special as sc
from scipy.integrate import odeint
import utility as psu
import scipy.integrate as integ
from scipy.optimize import curve_fit
from scipy import stats
import time
from matplotlib.colors import LogNorm
from numpy.random import randn
import matplotlib.colors as colors
import matplotlib.cbook as cbook
from matplotlib import cm
import os
import process_abalone_utility as pau

# %%
file_LED = '/data/abalone/ABALONE_RampingUp/2021_08_12_T0841_ABALONE_11kV_SiPM2_32V_LED300V.dat'
avolt = 11
dataLED = pau.process_abalone_data(filename=file_LED,nn=0,nplot=10,volts=avolt,sipmv=32,ledv='3')
# Out:
# /data/abalone/ABALONE_RampingUp/2021_08_12_T0841_ABALONE_11kV_SiPM2_32V_LED300V.dat Number of events 595291.0
# Total events number: 595291
# event n. 0 time to process: 0.02
# event n. 100000 time to process: 10.75
# event n. 200000 time to process: 21.46
# event n. 300000 time to process: 32.19
# event n. 400000 time to process: 42.91
# event n. 500000 time to process: 53.64

# %%
pau.plot_data(data=dataLED,fvolt=avolt,low=-1, high=4,low_max=0.5,high_max=4,low_en=1, high_en=100,
              low_fom=0.6,high_fom=1,high_rt=30)

# %%
new_data, new_wf = pau.select_data(dataLED,filename=file_LED,entr_cut=200,max_cut=1,area_cut=(0,1e7),
                                   pos_cut=(500,550),rt_cut=0,events=20, save=1,volts=avolt,sipmv=32,ledv='3')
# Out:
# /data/abalone/ABALONE_RampingUp/2021_08_12_T0841_ABALONE_11kV_SiPM2_32V_LED300V.dat Number of events 595291.0
# n. events 0 waveform samples 1024
# Events rejected by areaup 0 -> 0.0 %
#
# n. events 113885 waveform samples 1024
# Events rejected by areadown 113885 -> 19.130979638529727 %
#
# n. events 0 waveform samples 1024
# Events rejected by entropy 0 -> 0.0 %
#
# n. events 0 waveform samples 1024
# Events rejected by max 0 -> 0.0 %
#
# n. events 259 waveform samples 1024
# Events rejected by risetime 259 -> 0.043508132997139216 %
#
# n. events 540258 waveform samples 1024
# Events rejected by max position 540258 -> 90.7552776709206 %
#
# n. events 36685 waveform samples 1024
# /usr/share/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:2377: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->floating,key->block2_values] [items->['area_filt', 'width']]
#
#   return pytables.to_hdf(path_or_buf, key, self, **kwargs)
# Events selected  36685 -> 6.1625322741314745 %

# %%
pau.plot_data(data=new_data,fvolt=avolt,low=0.1, high=3,low_max=0.5,high_max=4,low_en=2, high_en=5,
          low_fom=0.75,high_fom=1)

# %%
wf2 = new_wf[(new_data['area']>10)&(new_data['area']<20)]
psu.plot_waveforms( wf2,events=20,tlim=(4.5,7.5))
# Out:
# n. events 7497 waveform samples 1024

# %%
pau.plot_pe_spectrum(new_data['area'], volts=avolt, low=0, high=100, bins=300, ledv=3)

# %%
peakint = pau.calculate_integrals( new_wf, nn=0, volts=avolt, sipmv = 32, ledv = '4', plot = 0, save = 1 )

# %%
pau.plot_pe_spectrum(peakint, volts=avolt, low=0, high=100, bins=300, ledv=4)

# %%
file_LED2 = '/data/abalone/ABALONE_RampingUp/2021_08_12_T0902_ABALONE_11kV_SiPM2_32V_LED400V.dat'
dataLED2 = pau.process_abalone_data(filename=file_LED2,nn=0,nplot=10,volts=avolt,sipmv=32,ledv='4')
# Out:
# /data/abalone/ABALONE_RampingUp/2021_08_12_T0902_ABALONE_11kV_SiPM2_32V_LED400V.dat Number of events 595572.0
# Total events number: 595572
# event n. 0 time to process: 0.00
# event n. 100000 time to process: 12.98
# event n. 200000 time to process: 25.92
# event n. 300000 time to process: 38.83
# event n. 400000 time to process: 51.75
# event n. 500000 time to process: 64.63

# %%
pau.plot_data(data=dataLED2,fvolt=avolt,low=-1, high=4,low_max=0.5,high_max=4,low_en=1, high_en=100,
              low_fom=0.6,high_fom=1,high_rt=30)

# %%
new_data2, new_wf2 = pau.select_data(dataLED2,filename=file_LED2,entr_cut=200,max_cut=1,area_cut=(0,1e7),
                                   pos_cut=(500,550),rt_cut=0,events=20, save=1,volts=avolt,sipmv=32,ledv='4')
# Out:
# /data/abalone/ABALONE_RampingUp/2021_08_12_T0902_ABALONE_11kV_SiPM2_32V_LED400V.dat Number of events 595572.0
# n. events 0 waveform samples 1024
# Events rejected by areaup 0 -> 0.0 %
#
# n. events 28695 waveform samples 1024
# Events rejected by areadown 28695 -> 4.818057262597973 %
#
# n. events 0 waveform samples 1024
# Events rejected by entropy 0 -> 0.0 %
#
# n. events 0 waveform samples 1024
# Events rejected by max 0 -> 0.0 %
#
# n. events 46 waveform samples 1024
# Events rejected by risetime 46 -> 0.00772366733157368 %
#
# n. events 157382 waveform samples 1024
# Events rejected by max position 157382 -> 26.425352434298453 %
#
# n. events 365268 waveform samples 1024
# Events selected  365268 -> 61.330619975418585 %

# %%
pau.plot_data(data=new_data2,fvolt=avolt,low=0.1, high=3,low_max=0.5,high_max=4,low_en=2, high_en=5,
          low_fom=0.75,high_fom=1)

# %%
wf2 = new_wf2[(new_data2['area']>10)&(new_data2['area']<20)]
psu.plot_waveforms( wf2,events=20,tlim=(4.5,7.5))
# Out:
# n. events 33080 waveform samples 1024

# %%
pau.plot_pe_spectrum(new_data2['area'], volts=avolt, low=0, high=100, bins=300, ledv=4)
