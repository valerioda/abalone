# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.integrate import quad
import scipy.special as sc
from scipy.integrate import odeint
import scipy.integrate as integ
from scipy.optimize import curve_fit
import simulation_utility as su
import matplotlib.mlab as mlab
import matplotlib.pyplot as pyplot
from scipy.stats import chisquare
import time
import json
import os

# %% [markdown]
# SIMULATION WITH 1PE (V)

# %%
wfs1 = su.read_waveforms_from_json(PE = 1, plot=True)
# Out:
# Number of waveforms 37265, time to read 29.83

# %%
for i in range(5) :
    listpeaks = su.search_peaks(wfs1[i],5,0.5,plot=False)
    ints = su.integral_simulation_peaks(wfs1[i],listpeaks,-5,0,50,100,5,20,10,plot=1,central=0)

# %%
for i in range(10):
    listpeaks = su.search_peaks(wfs1[i],5,0.5,plot=False)
    ints = su.integral_simulation_peaks(wfs1[i],listpeaks,-100,100,200,600,30,40,10,plot=1)

# %%
integrals1 = su.calculate_integrals(wfs1,PE=1,angle=0)
# Out:
# event n. 0 time to process: 0.01
# event n. 1000 time to process: 5.95
# event n. 2000 time to process: 11.64
# event n. 3000 time to process: 17.63
# event n. 4000 time to process: 23.53
# event n. 5000 time to process: 29.62
# event n. 6000 time to process: 35.81
# event n. 7000 time to process: 41.74
# event n. 8000 time to process: 47.87
# event n. 9000 time to process: 53.85
# event n. 10000 time to process: 59.69
# event n. 11000 time to process: 65.73
# event n. 12000 time to process: 71.64
# event n. 13000 time to process: 77.71
# event n. 14000 time to process: 83.52
# event n. 15000 time to process: 89.50
# event n. 16000 time to process: 95.29
# event n. 17000 time to process: 101.52
# event n. 18000 time to process: 107.54
# event n. 19000 time to process: 113.65
# event n. 20000 time to process: 119.53
# event n. 21000 time to process: 125.39
# event n. 22000 time to process: 131.30
# event n. 23000 time to process: 137.32
# event n. 24000 time to process: 143.23
# ...

# %% [markdown]
# SIMULATION WITH 2PE (V)

# %%
wfs2 = su.read_waveforms_from_json(PE = 2, plot = True)
# Out:
# Number of waveforms 0, time to read 0.00
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-152-f23fb3e3a313> in <module>
# ----> 1 wfs2 = su.read_waveforms_from_json(PE = 2, plot = True)
#
# ~/ABBY_ANALISI/abalone/simulation_analysis/simulation_utility.py in read_waveforms_from_json(PE, angle, plot)
#      32         plt.figure(figsize=(8,4.5))
#      33         for i in range(10):
# ---> 34             plt.plot(wfs[i],label=f'waveform {i}')
#      35         plt.xlabel('time (ns)', ha='right', x=1)
#      36         plt.ylabel('voltages (a.u.)', ha='right', y=1)
#
# IndexError: list index out of range

# %%
for i in range(5) :
    listpeaks = su.search_peaks(wfs2[i],5,0.5,plot=False)
    ints = su.integral_simulation_peaks(wfs2[i],listpeaks,-5,0,50,100,5,8,10,plot=1,central=0)

# %%
for i in range(10):
    listpeaks = su.search_peaks(wfs2[i],5,0.5,plot=False)
    ints = su.integral_simulation_peaks(wfs2[i],listpeaks,-40,100,200,600,15,8,10,plot=1)

# %%
integrals2 = su.calculate_integrals(wfs2,PE=2,angle=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-9658e2c61638> in <module>
# ----> 1 integrals2 = su.calculate_integrals(wfs2,PE=2,angle=0)
#
# NameError: name 'wfs2' is not defined

# %% [markdown]
# SIMULATION WITH 3PE (V)

# %%
wfs3 = su.read_waveforms_from_json(PE = 3, plot = True)
# Out:
# Number of waveforms 10005, time to read 9.69

# %%
for i in range(5) :
    listpeaks = su.search_peaks(wfs3[i],5,0.5,plot=False)
    ints = su.integral_simulation_peaks(wfs3[i],listpeaks,-5,0,50,100,5,8,10,plot=1,central=0)

# %%
for i in range(10):
    listpeaks = su.search_peaks(wfs3[i],5,0.5,plot=False)
    ints = su.integral_simulation_peaks(wfs3[i],listpeaks,-40,100,200,600,15,8,10,plot=1)

# %%
for i in range(20):
    listpeaks = su.search_peaks(wfs3[i],5,0.5,plot=False)
    ints = su.integral_simulation_peaks(wfs3[i],listpeaks,-50,100,200,600,15,8,10,plot=1)

# %%
for i in range(30):
    listpeaks = su.search_peaks(wfs3[i],5,0.5,plot=False)
    ints = su.integral_simulation_peaks(wfs3[i],listpeaks,-60,100,200,600,15,8,10,plot=1)

# %%
integrals3 = su.calculate_integrals(wfs3, PE = 3, angle = 0)
# Out:
# event n. 0 time to process: 0.00
# event n. 1000 time to process: 4.48
# event n. 2000 time to process: 8.90
# event n. 3000 time to process: 15.65
# event n. 4000 time to process: 22.56
# event n. 5000 time to process: 29.54
# event n. 6000 time to process: 36.65
# event n. 7000 time to process: 43.37
# event n. 8000 time to process: 50.10
# event n. 9000 time to process: 57.35
# event n. 10000 time to process: 64.26
# n. events: 3PE=4849

# %% [markdown]
# SIMULATION 4PE (V)

# %%
wfs4 = su.read_waveforms_from_json(PE = 4, plot=True)
# Out:
# Number of waveforms 10005, time to read 8.07

# %%
for i in range(5) :
    listpeaks = su.search_peaks(wfs4[i],5,0.5,plot=False)
    ints = su.integral_simulation_peaks(wfs4[i],listpeaks,-5,0,50,100,5,8,10,plot=1,central=0)

# %%
integrals4 = su.calculate_integrals(wfs4, PE = 4, angle = 0)
# Out:
# event n. 0 time to process: 0.02
# event n. 1000 time to process: 5.38
# event n. 2000 time to process: 10.71
# event n. 3000 time to process: 16.03
# event n. 4000 time to process: 21.26
# event n. 5000 time to process: 26.81
# event n. 6000 time to process: 32.31
# event n. 7000 time to process: 37.99
# event n. 8000 time to process: 43.16
# event n. 9000 time to process: 48.60
# event n. 10000 time to process: 54.39
# n. events: 4PE=3370

# %% [markdown]
# SIMULATION 5PE (G)

# %%
wfs5 = su.read_waveforms_from_json(PE = 5, plot=True)
# Out:
# Number of waveforms 10005, time to read 7.95

# %%
for i in range(5) :
    listpeaks = su.search_peaks(wfs5[i],5,0.5,plot=False)
    ints = su.integral_simulation_peaks(wfs5[i],listpeaks,-5,0,50,100,5,8,10,plot=1,central=0)

# %%
integrals5 = su.calculate_integrals(wfs5, PE = 5, angle = 0)
# Out:
# event n. 0 time to process: 0.01
# event n. 1000 time to process: 2.77
# event n. 2000 time to process: 5.66
# event n. 3000 time to process: 8.50
# event n. 4000 time to process: 11.44
# event n. 5000 time to process: 14.28
# event n. 6000 time to process: 17.22
# event n. 7000 time to process: 19.73
# event n. 8000 time to process: 22.38
# event n. 9000 time to process: 25.30
# event n. 10000 time to process: 28.20
# n. events: 5PE=2490

# %% [markdown]
# SIMULATION 6PE

# %%
wfs6 = su.read_waveforms_from_json(PE = 6, plot=True)
# Out:
# Number of waveforms 10005, time to read 8.20

# %%
for i in range(5) :
    listpeaks = su.search_peaks(wfs6[i],5,0.5,plot=False)
    ints = su.integral_simulation_peaks(wfs6[i],listpeaks,-5,0,50,100,5,8,10,plot=1,central=0)

# %%
integrals6 = su.calculate_integrals(wfs6, PE = 6, angle = 0)
# Out:
# event n. 0 time to process: 0.00
# event n. 1000 time to process: 2.33
# event n. 2000 time to process: 4.78
# event n. 3000 time to process: 7.36
# event n. 4000 time to process: 9.85
# event n. 5000 time to process: 12.27
# event n. 6000 time to process: 14.52
# event n. 7000 time to process: 16.91
# event n. 8000 time to process: 19.42
# event n. 9000 time to process: 21.95
# event n. 10000 time to process: 24.57
# n. events: 6PE=1893

# %% [markdown]
# HISTOGRAMS 1PE, 2PE, 3PE

# %%
def gaussian(x, a, mu, sigma):
    return a*np.exp(-(x-mu)**2/(2. * sigma **2))

def chisq(fobs, fexp, errors):
    return np.sum((fobs - fexp) ** 2 / (errors ** 2))


def fitgaussian(integrals1, xrange=(1000,25000), bins=200, range1=(6000,11000), guess1 = (250, 5000, 1000)): #range2=(9000,12000), guess2 = (50,11000,1000)):
    print(f'n. events: 1PE={len(integrals1)}')
    h1, x1 = np.histogram(integrals1,bins=bins,range=xrange,density=1)
    #h2, x2 = np.histogram(integrals2,bins=bins,range=xrange,density=1)

    idx1, idx2 = np.where(x1>range1[0])[0][0], np.where(x1>range1[1])[0][0]
    popt, pcov = curve_fit(gaussian, x1[idx1:idx2], h1[idx1:idx2], p0=guess1)
    perr = np.sqrt(np.diag(pcov))
    print('1PE fit results',*popt)
    
    integrals1 = np.load(f'integrals/integrals_PE1_angle0.npy')
    fobs = integrals1
    print('fobs', fobs)
    fexp = (integrals1, *popt)
    print('fexp', fexp)
    errors = np.sqrt(integrals1)
    
    chi2 = chisq(fobs,fexp,errors)
    print('chisquare', chisq)
    
    
    
    #idxx1, idxx2 = np.where(x2>range2[0])[0][0], np.where(x2>range2[1])[0][0]
    #popt2, pcov2 = curve_fit(gaussian, x2[idxx1:idxx2], h2[idxx1:idxx2], p0=guess2)
    #perr2 = np.sqrt(np.diag(pcov))
    #print('2PE fit results',*popt2)
    
    
    plt.figure(figsize=(8,4.5))
    plt.plot(x1[1:],h1,label='Simulation with 1 PE')
#plt.plot(x2[1:],h2,label='Simulation with 2 PE')
    plt.plot(x1[idx1:idx2], gaussian(x1[idx1:idx2], *popt),label=f'SPE at {popt[1]:.3f}')
#plt.plot(x2[idxx1:idxx2], gaussian(x2[idxx1:idxx2], *popt2),label=f'DPE at {popt2[1]:.1f}')
    plt.legend()

#integrals1 = np.load(f'integrals/integrals_PE1_angle0.npy')
#integrals2 = np.load(f'integrals/integrals_PE2_angle0.npy')
#integrals3 = np.load(f'integrals/integrals_PE3_angle0.npy')
#print(f'n. events: 1PE={len(integrals1)}, 2PE={len(integrals2)}, 3PE={len(integrals3)}')
#mu1= np.mean(integrals1)
#sigma1= np.std (integrals1)
#print(mu1)
#print(sigma1)
#mu,sigma=norm.fit(integrals1)
#print(mu,sigma)
#n1, bins1, patches1=plt.hist(integrals1,200, density=True, color='blue')
#n2, bins2, ignored2=plt.hist(integrals2,200, range=(1000,35000),density=True,histtype='step',label=f'2 PE')
#count2, bins2, ignored2=plt.hist(integrals2,bins=200,range=(1000,35000),density=True,histtype='step',label='2 PE', color='coral')
#a = plt.hist(integrals3,bins=200,range=(1000,35000),density=True,histtype='step',label='3 PE', color= 'darkgreen')
#mu1, sigma1 = 5100, 1000
#mu2, sigma2 = 5100, 500
#y1 = norm.pdf(bins1, mu1, sigma1)
#l1 = plt.plot(bins1, y1, 'r--',linewidth=2)
#y2 = norm.pdf(bins2, mu2, sigma2)
#l2 = plt.plot(bins2, y2, 'r--', linewidth=2)
#plt.plot(bins2, gaussian,linewidth=2,color='r')
#plt.plot(bins2, 1/(sigma2 * np.sqrt(2 * np.pi))*np.exp( - (bins2 - mu)**2 / (2 * sigma2**2) ),linewidth=2, color='b')


#plt.xlabel('Area')
#plt.ylabel('Counts')
#plt.title(r'$\mathrm{Histogram\ of\ IQ:}\ \mu=%.3f,\ \sigma=%.3f$' %(mu, sigma))
#plt.ylim(0,0.00035)
#plt.show()
#a = plt.hist(integrals4,bins=200,range=(1000,35000),density=0,histtype='step',label='4 PE', color= 'red')
#a = plt.hist(integrals5,bins=200,range=(1000,35000),density=0,histtype='step',label='5 PE', color= 'black')
#a = plt.hist(integrals6,bins=200,range=(1000,35000),density=0,histtype='step',label='6 PE', color= 'blue')
#plt.yscale('log')
#plt.legend()

# %%
integrals1 = np.load(f'integrals/integrals_PE1_angle0.npy')
#integrals2 = np.load(f'integrals/integrals_PE2_angle0.npy')
fitgaussian(integrals1, xrange=(100,22000), bins=250, range1=(6500,10800), guess1 = (250, 5100, 1000))
# Out:
# n. events: 1PE=27078
# 1PE fit results 0.00023793681497210264 8392.046005039552 1208.6095911886162
# fobs [ 9955.98300459  9470.27884984 36808.10358943 ...  9518.3323687
#   5951.53944449  9876.62607686]
# fexp (array([ 9955.98300459,  9470.27884984, 36808.10358943, ...,
#         9518.3323687 ,  5951.53944449,  9876.62607686]), 0.00023793681497210264, 8392.046005039552, 1208.6095911886162)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-5bef9e8ac6e6> in <module>
#       1 integrals1 = np.load(f'integrals/integrals_PE1_angle0.npy')
#       2 #integrals2 = np.load(f'integrals/integrals_PE2_angle0.npy')
# ----> 3 fitgaussian(integrals1, xrange=(100,22000), bins=250, range1=(6500,10800), guess1 = (250, 5100, 1000))
#
# <ipython-input-55-dfac936a9772> in fitgaussian(integrals1, xrange, bins, range1, guess1)
#      23     errors = np.sqrt(integrals1)
#      24
# ...

# %%
plt.figure(figsize=(8,4.5))
integrals1 = np.load(f'integrals/integrals_PE1_angle0.npy')
#integrals2 = np.load(f'integrals/integrals_PE2_angle0.npy')
#integrals3 = np.load(f'integrals/integrals_PE3_angle0.npy')
#integrals4 = np.load(f'integrals/integrals_PE4_angle0.npy')
#integrals5 = np.load(f'integrals/integrals_PE5_angle0.npy')
#integrals6 = np.load(f'integrals/integrals_PE6_angle0.npy')
#print(f'n. events: 1PE={len(integrals1)}, 2PE={len(integrals2)}, 3PE={len(integrals3)}')
a=plt.hist(integrals1,bins=200,range=(1000,35000),density=False,histtype='step',label=f'1 PE')
#a=plt.hist(integrals2,bins=200,range=(1000,35000),density=,histtype='step',label='2 PE', color='coral')
#a = plt.hist(integrals3,bins=200,range=(1000,35000),density=True,histtype='step',label='3 PE', color= 'darkgreen')
#mu1, sigma1 = 5100,1000
#mu2, sigma2 = 10100, 5000
#plt.plot(bins1, 1/(sigma1 * np.sqrt(2 * np.pi))*np.exp( - (bins1 - mu1)**2 / (2 * sigma1**2) ),linewidth=2, color='b')
plt.show()

#a = plt.hist(integrals4,bins=200,range=(1000,35000),density=0,histtype='step',label='4 PE', color= 'red')
#a = plt.hist(integrals5,bins=200,range=(1000,35000),density=0,histtype='step',label='5 PE', color= 'black')
#a = plt.hist(integrals6,bins=200,range=(1000,35000),density=0,histtype='step',label='6 PE', color= 'blue')
#plt.ylim(0,)
#plt.yscale('log')
#plt.legend()

# %%
integrals1 = su.simple_integral_central_peak( wfs1, 70, 600)
#integrals2 = su.simple_integral_central_peak( wfs2, 70, 600)
#integrals3 = su.simple_integral_central_peak( wfs3, 70, 600)
#integrals4 = su.simple_integral_central_peak( wfs4, 70, 600)
#integrals5 = su.simple_integral_central_peak( wfs5, 70, 600)
#integrals6 = su.simple_integral_central_peak( wfs6, 70, 600)

# %%
plt.figure(figsize=(8,4.5))
print(f'n. events: 1PE={len(integrals1)}, 2PE={len(integrals2)}, 3PE={len(integrals3)}')
a = plt.hist(integrals1,bins=200,range=(1000,35000),density=0,histtype='step',label='1 PE')
#a = plt.hist(integrals2,bins=200,range=(1000,35000),density=0,histtype='step',label='2 PE')
#a = plt.hist(integrals3,bins=200,range=(1000,40000),density=0,histtype='step',label='3 PE')
#a = plt.hist(integrals4,bins=200,range=(1000,40000),density=0,histtype='step',label='4 PE')
#a = plt.hist(integrals4,bins=200,range=(1000,40000),density=0,histtype='step',label='5 PE')
#a = plt.hist(integrals4,bins=200,range=(1000,40000),density=0,histtype='step',label='6 PE')
#plt.yscale('log')
#plt.ylim(0,450)
plt.legend()
# Out:
# n. events: 1PE=37265, 2PE=6514, 3PE=4849
