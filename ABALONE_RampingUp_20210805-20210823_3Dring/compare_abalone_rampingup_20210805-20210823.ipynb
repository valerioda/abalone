# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.integrate import quad
import scipy.special as sc
from scipy.integrate import odeint
import utility as psu
import scipy.integrate as integ
from scipy.optimize import curve_fit
from scipy import stats
import time
from matplotlib.colors import LogNorm
from numpy.random import randn
import matplotlib.colors as colors
import matplotlib.cbook as cbook
from matplotlib import cm
import os
import process_abalone_utility as pau

# %%
def compare_pe_spectrum(area1,area2,area3=None,area4=None,area5=None, bins = 200,
                        volts = (7,8,9,10,11), ledv = 3, low = 0, high = 100):
    area_space = np.linspace(low,high, bins)
    h1, t1 = np.histogram(area1, bins=area_space)
    h2, t2 = np.histogram(area2, bins=area_space)
    plt.figure(figsize=(12,6))
    a1 = plt.hist(area1,bins=area_space,histtype='step',lw=2,label=f'ABALONE at {volts[0]} kV')
    a2 = plt.hist(area2,bins=area_space,histtype='step',lw=2,label=f'ABALONE at {volts[1]} kV')
    if area3 is not None:
        h3, t3 = np.histogram(area3, bins=area_space)
        a3 = plt.hist(area3,bins=area_space,histtype='step',lw=2,label=f'ABALONE at {volts[2]} kV')
    if area4 is not None:
        h4, t4 = np.histogram(area4, bins=area_space)
        a4 = plt.hist(area4,bins=area_space,histtype='step',lw=2,label=f'ABALONE at {volts[3]} kV')
    if area5 is not None:
        h5, t5 = np.histogram(area5, bins=area_space)
        a5 = plt.hist(area5,bins=area_space,histtype='step',lw=2,label=f'ABALONE at {volts[4]} kV')
    plt.title(f'PE spectrum comparison - LED at {ledv:.1f} V')
    plt.xlabel('area (ADC x $\mu$s)',ha='right',x=1)
    plt.ylabel('counts',ha='right',y=1)
    plt.legend(fontsize=14)

# %%
df_11 = pd.read_hdf('processed_data/data_ABALONE_11kV_SiPM2_32V_LED_3V.h5')
df_14 = pd.read_hdf('processed_data/data_ABALONE_14kV_SiPM2_32V_LED_3V.h5')
df_17 = pd.read_hdf('processed_data/data_ABALONE_17kV_SiPM2_32V_LED_3V.h5')
df_20 = pd.read_hdf('processed_data/data_ABALONE_20kV_SiPM2_32V_LED_3V.h5')

# %%
compare_pe_spectrum(df_11['area'],df_14['area'],df_17['area'],df_20['area'], volts=(11,14,17,20), low=0, high=120, bins=300, ledv=3)

# %%
area7 = np.load('processed_data/peakint_ABALONE_7kV_SiPM2_32V_LED_4V.npy')
area8 = np.load('processed_data/peakint_ABALONE_8kV_SiPM2_32V_LED_4V.npy')
area9 = np.load('processed_data/peakint_ABALONE_9kV_SiPM2_32V_LED_4V.npy')
area10 = np.load('processed_data/peakint_ABALONE_10kV_SiPM2_32V_LED_4V.npy')

data7 = pd.read_hdf('processed_data/data_ABALONE_7kV_SiPM2_32V_LED_4V.h5')
data8 = pd.read_hdf('processed_data/data_ABALONE_8kV_SiPM2_32V_LED_4V.h5')
data9 = pd.read_hdf('processed_data/data_ABALONE_9kV_SiPM2_32V_LED_4V.h5')
data10 = pd.read_hdf('processed_data/data_ABALONE_10kV_SiPM2_32V_LED_4V.h5')
data11 = pd.read_hdf('processed_data/data_ABALONE_11kV_SiPM2_32V_LED_4V.h5')

# %%
compare_pe_spectrum(data7['area'],data8['area'],data9['area'],data10['area'],data11['area'], low=0, high=120, bins=300, ledv=4)

# %%
df5_7 = pd.read_hdf('processed_data/data_ABALONE_7kV_SiPM2_32V_LED_5V.h5')
df5_8 = pd.read_hdf('processed_data/data_ABALONE_8kV_SiPM2_32V_LED_5V.h5')
df5_9 = pd.read_hdf('processed_data/data_ABALONE_9kV_SiPM2_32V_LED_5V.h5')
df5_10 = pd.read_hdf('processed_data/data_ABALONE_10kV_SiPM2_32V_LED_5V.h5')

# %%
compare_pe_spectrum(df5_7['area'],df5_8['area'],df5_9['area'],df5_10['area'], volts=(7,8,9,10), low=0, high=200, bins=300, ledv=5)
