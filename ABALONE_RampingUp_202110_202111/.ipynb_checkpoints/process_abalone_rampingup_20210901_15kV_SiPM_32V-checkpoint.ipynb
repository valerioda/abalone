# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.integrate import quad
import scipy.special as sc
from scipy.integrate import odeint
import utility as psu
import scipy.integrate as integ
from scipy.optimize import curve_fit
from scipy import stats
import time
from matplotlib.colors import LogNorm
from numpy.random import randn
import matplotlib.colors as colors
import matplotlib.cbook as cbook
from matplotlib import cm
import os
import process_abalone_utility as pau

# %%
file_LED = '/data/abalone/ABALONE_RampingUp/2021_08_31_T1538_ABALONE_14kV_SiPM2_32V_LED300V.dat'
avolt = 14
dataLED = pau.process_abalone_data(filename=file_LED,nn=0,nplot=10,volts=avolt,sipmv=32,ledv='3')
# Out:
# /data/abalone/ABALONE_RampingUp/2021_08_31_T1538_ABALONE_14kV_SiPM2_32V_LED300V.dat Number of events 594868.0
# Total events number: 594868
# event n. 0 time to process: 0.02
# event n. 100000 time to process: 11.28
# event n. 200000 time to process: 22.53
# event n. 300000 time to process: 33.81
# event n. 400000 time to process: 45.10
# event n. 500000 time to process: 56.38

# %%
pau.plot_data(data=dataLED,fvolt=avolt,low=-1, high=4,low_max=0.5,high_max=4,low_en=1, high_en=100,
              low_fom=0.6,high_fom=1,high_rt=30)

# %%
new_data, new_wf = pau.select_data(dataLED,filename=file_LED,entr_cut=200,max_cut=1,area_cut=(0,1e7),
                                   pos_cut=(500,550),rt_cut=0,events=20, save=1,volts=avolt,sipmv=32,ledv='3')
# Out:
# /data/abalone/ABALONE_RampingUp/2021_08_31_T1538_ABALONE_14kV_SiPM2_32V_LED300V.dat Number of events 594868.0
# n. events 0 waveform samples 1024
# Events rejected by areaup 0 -> 0.0 %
#
# n. events 104865 waveform samples 1024
# Events rejected by areadown 104865 -> 17.628280559720814 %
#
# n. events 0 waveform samples 1024
# Events rejected by entropy 0 -> 0.0 %
#
# n. events 0 waveform samples 1024
# Events rejected by max 0 -> 0.0 %
#
# n. events 97 waveform samples 1024
# Events rejected by risetime 97 -> 0.016306138504676666 %
#
# n. events 513766 waveform samples 1024
# Events rejected by max position 513766 -> 86.36638716488363 %
#
# n. events 61839 waveform samples 1024
# /usr/share/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:2377: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->floating,key->block2_values] [items->['area_filt', 'width']]
#
#   return pytables.to_hdf(path_or_buf, key, self, **kwargs)
# Events selected  61839 -> 10.395415453512376 %

# %%
pau.plot_data(data=new_data,fvolt=avolt,low=0.1, high=3,low_max=0.5,high_max=4,low_en=2, high_en=5,
          low_fom=0.75,high_fom=1)

# %%
wf2 = new_wf[(new_data['area']>10)&(new_data['area']<20)]
psu.plot_waveforms( wf2,events=20,tlim=(4.5,7.5))
# Out:
# n. events 6761 waveform samples 1024

# %%
pau.plot_pe_spectrum(new_data['area'], volts=avolt, low=0, high=100, bins=300, ledv=3)

# %%
#peakint = pau.calculate_integrals( new_wf, nn=0, volts=avolt, sipmv = 32, ledv = '4', plot = 0, save = 1 )

# %%
#pau.plot_pe_spectrum(peakint, volts=avolt, low=0, high=100, bins=300, ledv=4)

# %%
file_LED = '/data/abalone/ABALONE_RampingUp/2021_08_31_T1551_ABALONE_14kV_SiPM2_32V_LED400V.dat'
dataLED = pau.process_abalone_data(filename=file_LED,nn=0,nplot=10,volts=avolt,sipmv=32,ledv='4')
# Out:
# /data/abalone/ABALONE_RampingUp/2021_08_31_T1551_ABALONE_14kV_SiPM2_32V_LED400V.dat Number of events 593611.0
# Total events number: 593611
# event n. 0 time to process: 0.00
# event n. 100000 time to process: 13.87
# event n. 200000 time to process: 27.77
# event n. 300000 time to process: 41.66
# event n. 400000 time to process: 55.63
# event n. 500000 time to process: 69.43

# %%
new_data, new_wf = pau.select_data(dataLED,filename=file_LED,entr_cut=200,max_cut=1,area_cut=(0,1e7),
                                   pos_cut=(500,550),rt_cut=0,events=20, save=1,volts=avolt,sipmv=32,ledv='4')
# Out:
# /data/abalone/ABALONE_RampingUp/2021_08_31_T1551_ABALONE_14kV_SiPM2_32V_LED400V.dat Number of events 593611.0
# n. events 0 waveform samples 1024
# Events rejected by areaup 0 -> 0.0 %
#
# n. events 6483 waveform samples 1024
# Events rejected by areadown 6483 -> 1.0921293574411526 %
#
# n. events 0 waveform samples 1024
# Events rejected by entropy 0 -> 0.0 %
#
# n. events 0 waveform samples 1024
# Events rejected by max 0 -> 0.0 %
#
# n. events 8 waveform samples 1024
# Events rejected by risetime 8 -> 0.0013476839209515996 %
#
# n. events 61004 waveform samples 1024
# Events rejected by max position 61004 -> 10.276763739216422 %
#
# n. events 507322 waveform samples 1024
# Events selected  507322 -> 85.46371276812593 %

# %%
pau.plot_pe_spectrum(new_data['area'], volts=avolt, low=0, high=100, bins=300, ledv=4)
