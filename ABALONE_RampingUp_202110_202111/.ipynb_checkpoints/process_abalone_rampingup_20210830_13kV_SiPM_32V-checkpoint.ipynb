# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.integrate import quad
import scipy.special as sc
from scipy.integrate import odeint
import utility as psu
import scipy.integrate as integ
from scipy.optimize import curve_fit
from scipy import stats
import time
from matplotlib.colors import LogNorm
from numpy.random import randn
import matplotlib.colors as colors
import matplotlib.cbook as cbook
from matplotlib import cm
import os
import process_abalone_utility as pau

# %%
file_LED = '/data/abalone/ABALONE_RampingUp/2021_08_30_T0925_ABALONE_12kV_SiPM2_32V_LED300V.dat'
avolt = 12
dataLED = pau.process_abalone_data(filename=file_LED,nn=0,nplot=10,volts=avolt,sipmv=32,ledv='3')
# Out:
# /data/abalone/ABALONE_RampingUp/2021_08_30_T0925_ABALONE_12kV_SiPM2_32V_LED300V.dat Number of events 595159.0
# Total events number: 595159
# event n. 0 time to process: 0.02
# event n. 100000 time to process: 10.87
# event n. 200000 time to process: 21.71
# event n. 300000 time to process: 32.54
# event n. 400000 time to process: 43.34
# event n. 500000 time to process: 54.19

# %%
pau.plot_data(data=dataLED,fvolt=avolt,low=-1, high=4,low_max=0.5,high_max=4,low_en=1, high_en=100,
              low_fom=0.6,high_fom=1,high_rt=30)

# %%
new_data, new_wf = pau.select_data(dataLED,filename=file_LED,entr_cut=200,max_cut=1,area_cut=(0,1e7),
                                   pos_cut=(500,550),rt_cut=0,events=20, save=1,volts=avolt,sipmv=32,ledv='3')
# Out:
# /data/abalone/ABALONE_RampingUp/2021_08_30_T0925_ABALONE_12kV_SiPM2_32V_LED300V.dat Number of events 595159.0
# n. events 0 waveform samples 1024
# Events rejected by areaup 0 -> 0.0 %
#
# n. events 105845 waveform samples 1024
# Events rejected by areadown 105845 -> 17.784323180864273 %
#
# n. events 0 waveform samples 1024
# Events rejected by entropy 0 -> 0.0 %
#
# n. events 0 waveform samples 1024
# Events rejected by max 0 -> 0.0 %
#
# n. events 106 waveform samples 1024
# Events rejected by risetime 106 -> 0.017810366641519325 %
#
# n. events 522362 waveform samples 1024
# Events rejected by max position 522362 -> 87.76847867544639 %
#
# n. events 53510 waveform samples 1024
# /usr/share/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:2377: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->floating,key->block2_values] [items->['area_filt', 'width']]
#
#   return pytables.to_hdf(path_or_buf, key, self, **kwargs)
# Events selected  53510 -> 8.990874707431123 %

# %%
pau.plot_data(data=new_data,fvolt=avolt,low=0.1, high=3,low_max=0.5,high_max=4,low_en=2, high_en=5,
          low_fom=0.75,high_fom=1)

# %%
wf2 = new_wf[(new_data['area']>10)&(new_data['area']<20)]
psu.plot_waveforms( wf2,events=20,tlim=(4.5,7.5))
# Out:
# n. events 8611 waveform samples 1024

# %%
pau.plot_pe_spectrum(new_data['area'], volts=avolt, low=0, high=100, bins=300, ledv=3)

# %%
#peakint = pau.calculate_integrals( new_wf, nn=0, volts=avolt, sipmv = 32, ledv = '4', plot = 0, save = 1 )

# %%
#pau.plot_pe_spectrum(peakint, volts=avolt, low=0, high=100, bins=300, ledv=4)

# %%
file_LED = '/data/abalone/ABALONE_RampingUp/2021_08_30_T0936_ABALONE_12kV_SiPM2_32V_LED400V.dat'
dataLED = pau.process_abalone_data(filename=file_LED,nn=0,nplot=10,volts=avolt,sipmv=32,ledv='4')
# Out:
# /data/abalone/ABALONE_RampingUp/2021_08_30_T0936_ABALONE_12kV_SiPM2_32V_LED400V.dat Number of events 593694.0
# Total events number: 593694
# event n. 0 time to process: 0.00
# event n. 100000 time to process: 13.32
# event n. 200000 time to process: 26.60
# event n. 300000 time to process: 40.03
# event n. 400000 time to process: 53.34
# event n. 500000 time to process: 66.68

# %%
new_data, new_wf = pau.select_data(dataLED,filename=file_LED,entr_cut=200,max_cut=1,area_cut=(0,1e7),
                                   pos_cut=(500,550),rt_cut=0,events=20, save=1,volts=avolt,sipmv=32,ledv='4')
# Out:
# /data/abalone/ABALONE_RampingUp/2021_08_30_T0936_ABALONE_12kV_SiPM2_32V_LED400V.dat Number of events 593694.0
# n. events 0 waveform samples 1024
# Events rejected by areaup 0 -> 0.0 %
#
# n. events 8299 waveform samples 1024
# Events rejected by areadown 8299 -> 1.3978581558850183 %
#
# n. events 0 waveform samples 1024
# Events rejected by entropy 0 -> 0.0 %
#
# n. events 0 waveform samples 1024
# Events rejected by max 0 -> 0.0 %
#
# n. events 7 waveform samples 1024
# Events rejected by risetime 7 -> 0.001179058572261131 %
#
# n. events 70524 waveform samples 1024
# Events rejected by max position 70524 -> 11.878846678592001 %
#
# n. events 488429 waveform samples 1024
# Events selected  488429 -> 82.26948562727601 %

# %%
pau.plot_pe_spectrum(new_data['area'], volts=avolt, low=0, high=100, bins=300, ledv=4)
