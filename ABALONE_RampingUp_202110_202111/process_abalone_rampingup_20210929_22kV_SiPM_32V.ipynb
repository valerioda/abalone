# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.integrate import quad
import scipy.special as sc
from scipy.integrate import odeint
import utility as psu
import scipy.integrate as integ
from scipy.optimize import curve_fit
from scipy import stats
import time
from matplotlib.colors import LogNorm
from numpy.random import randn
import matplotlib.colors as colors
import matplotlib.cbook as cbook
from matplotlib import cm
import os
import process_abalone_utility as pau
import process_utility as pu

# %%
file_LED = '/data/abalone/ABALONE_RampingUp/2021_09_29_T1319_ABALONE_22kV_SiPM2_32V_LED300V.dat'
avolt = 22
#dataLED = pau.process_abalone_data(filename=file_LED,nn=0,nplot=10,volts=avolt,sipmv=32,ledv='3')

# %%
pu.plot_waveforms( file_LED, events = 5 )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-96aabe6ccbcc> in <module>
# ----> 1 pu.plot_waveforms( file_LED, events = 5 )
#
# ~/abalone/process_utility.py in plot_waveforms(data, events)
#      22
#      23 def plot_waveforms( data, events = 5 ):
# ---> 24     dts = np.arange(0,data.shape[1]*10,10)
#      25     plt.figure(figsize=(12,6))
#      26     for i in range(events):
#
# AttributeError: 'str' object has no attribute 'shape'

# %%
pau.plot_data(data=dataLED,fvolt=avolt,low=-1, high=4,low_max=0.5,high_max=4,low_en=1, high_en=100,
              low_fom=0.6,high_fom=1,high_rt=30)

# %%
new_data, new_wf = pau.select_data(dataLED,filename=file_LED,entr_cut=200,max_cut=1,area_cut=(0,1e7),
                                   pos_cut=(500,550),rt_cut=0,events=20, save=1,volts=avolt,sipmv=32,ledv='3')
# Out:
# /data/abalone/ABALONE_RampingUp/2021_09_29_T1319_ABALONE_22kV_SiPM2_32V_LED300V.dat Number of events 591537.0
# n. events 0 waveform samples 1024
# Events rejected by areaup 0 -> 0.0 %
#
# n. events 96237 waveform samples 1024
# Events rejected by areadown 96237 -> 16.268973876528435 %
#
# n. events 0 waveform samples 1024
# Events rejected by entropy 0 -> 0.0 %
#
# n. events 0 waveform samples 1024
# Events rejected by max 0 -> 0.0 %
#
# n. events 134 waveform samples 1024
# Events rejected by risetime 134 -> 0.02265285180808639 %
#
# n. events 502567 waveform samples 1024
# Events rejected by max position 502567 -> 84.959520706228 %
#
# n. events 73491 waveform samples 1024
# /usr/share/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:2377: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->floating,key->block2_values] [items->['area_filt', 'width']]
#
#   return pytables.to_hdf(path_or_buf, key, self, **kwargs)
# Events selected  73491 -> 12.423736807672217 %

# %%
pau.plot_data(data=new_data,fvolt=avolt,low=0.1, high=3,low_max=0.5,high_max=4,low_en=2, high_en=5,
          low_fom=0.75,high_fom=1)

# %%
wf2 = new_wf[(new_data['area']>10)&(new_data['area']<20)]
psu.plot_waveforms( wf2,events=20,tlim=(4.5,7.5))
# Out:
# n. events 5072 waveform samples 1024

# %%
pau.plot_pe_spectrum(new_data['area'], volts=avolt, low=0, high=10, bins=300, ledv=3)

# %%
#peakint = pau.calculate_integrals( new_wf, nn=0, volts=avolt, sipmv = 32, ledv = '4', plot = 0, save = 1 )

# %%
#pau.plot_pe_spectrum(peakint, volts=avolt, low=0, high=100, bins=300, ledv=4)

# %%
file_LED = '/data/abalone/ABALONE_RampingUp/2021_09_29_T1330_ABALONE_22kV_SiPM2_32V_LED400V.dat'
dataLED = pau.process_abalone_data(filename=file_LED,nn=0,nplot=10,volts=avolt,sipmv=32,ledv='4')
# Out:
# /data/abalone/ABALONE_RampingUp/2021_09_29_T1330_ABALONE_22kV_SiPM2_32V_LED400V.dat Number of events 595497.0
# Total events number: 595497
# event n. 0 time to process: 0.00
# event n. 100000 time to process: 13.72
# event n. 200000 time to process: 27.43
# event n. 300000 time to process: 41.10
# event n. 400000 time to process: 54.78
# event n. 500000 time to process: 68.47

# %%
new_data, new_wf = pau.select_data(dataLED,filename=file_LED,entr_cut=200,max_cut=1,area_cut=(0,1e7),
                                   pos_cut=(500,550),rt_cut=0,events=20, save=1,volts=avolt,sipmv=32,ledv='4')
# Out:
# /data/abalone/ABALONE_RampingUp/2021_09_29_T1330_ABALONE_22kV_SiPM2_32V_LED400V.dat Number of events 595497.0
# n. events 0 waveform samples 1024
# Events rejected by areaup 0 -> 0.0 %
#
# n. events 3403 waveform samples 1024
# Events rejected by areadown 3403 -> 0.5714554397419298 %
#
# n. events 0 waveform samples 1024
# Events rejected by entropy 0 -> 0.0 %
#
# n. events 0 waveform samples 1024
# Events rejected by max 0 -> 0.0 %
#
# n. events 2 waveform samples 1024
# Events rejected by risetime 2 -> 0.00033585391698027025 %
#
# n. events 36412 waveform samples 1024
# Events rejected by max position 36412 -> 6.1145564125428 %
#
# n. events 549249 waveform samples 1024
# Events selected  549249 -> 92.23371402374822 %

# %%
pau.plot_pe_spectrum(new_data['area'], volts=avolt, low=0, high=150, bins=300, ledv=4)
