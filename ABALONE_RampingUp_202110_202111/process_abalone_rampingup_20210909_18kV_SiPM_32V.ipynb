# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.integrate import quad
import scipy.special as sc
from scipy.integrate import odeint
import utility as psu
import scipy.integrate as integ
from scipy.optimize import curve_fit
from scipy import stats
import time
from matplotlib.colors import LogNorm
from numpy.random import randn
import matplotlib.colors as colors
import matplotlib.cbook as cbook
from matplotlib import cm
import os
import process_abalone_utility as pau

# %%
file_LED = '/data/abalone/ABALONE_RampingUp/2021_09_09_T1009_ABALONE_18kV_SiPM2_32V_LED300V.dat'
avolt = 18
dataLED = pau.process_abalone_data(filename=file_LED,nn=0,nplot=10,volts=avolt,sipmv=32,ledv='3')
# Out:
# /data/abalone/ABALONE_RampingUp/2021_09_09_T1009_ABALONE_18kV_SiPM2_32V_LED300V.dat Number of events 595782.0
# Total events number: 595782
# event n. 0 time to process: 0.02
# event n. 100000 time to process: 11.61
# event n. 200000 time to process: 23.18
# event n. 300000 time to process: 34.75
# event n. 400000 time to process: 46.31
# event n. 500000 time to process: 57.84

# %%
pau.plot_data(data=dataLED,fvolt=avolt,low=-1, high=4,low_max=0.5,high_max=4,low_en=1, high_en=100,
              low_fom=0.6,high_fom=1,high_rt=30)

# %%
new_data, new_wf = pau.select_data(dataLED,filename=file_LED,entr_cut=200,max_cut=1,area_cut=(0,1e7),
                                   pos_cut=(500,550),rt_cut=0,events=20, save=1,volts=avolt,sipmv=32,ledv='3')
# Out:
# /data/abalone/ABALONE_RampingUp/2021_09_09_T1009_ABALONE_18kV_SiPM2_32V_LED300V.dat Number of events 595782.0
# n. events 0 waveform samples 1024
# Events rejected by areaup 0 -> 0.0 %
#
# n. events 96571 waveform samples 1024
# Events rejected by areadown 96571 -> 16.20911675747169 %
#
# n. events 0 waveform samples 1024
# Events rejected by entropy 0 -> 0.0 %
#
# n. events 0 waveform samples 1024
# Events rejected by max 0 -> 0.0 %
#
# n. events 133 waveform samples 1024
# Events rejected by risetime 133 -> 0.022323601585814947 %
#
# n. events 513748 waveform samples 1024
# Events rejected by max position 513748 -> 86.23086968052073 %
#
# n. events 65804 waveform samples 1024
# /usr/share/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:2377: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->floating,key->block2_values] [items->['area_filt', 'width']]
#
#   return pytables.to_hdf(path_or_buf, key, self, **kwargs)
# Events selected  65804 -> 11.04497953949599 %

# %%
pau.plot_data(data=new_data,fvolt=avolt,low=0.1, high=3,low_max=0.5,high_max=4,low_en=2, high_en=5,
          low_fom=0.75,high_fom=1)

# %%
wf2 = new_wf[(new_data['area']>10)&(new_data['area']<20)]
psu.plot_waveforms( wf2,events=20,tlim=(4.5,7.5))
# Out:
# n. events 4956 waveform samples 1024

# %%
pau.plot_pe_spectrum(new_data['area'], volts=avolt, low=0, high=100, bins=300, ledv=3)

# %%
#peakint = pau.calculate_integrals( new_wf, nn=0, volts=avolt, sipmv = 32, ledv = '4', plot = 0, save = 1 )

# %%
#pau.plot_pe_spectrum(peakint, volts=avolt, low=0, high=100, bins=300, ledv=4)

# %%
file_LED = '/data/abalone/ABALONE_RampingUp/2021_09_09_T1019_ABALONE_18kV_SiPM2_32V_LED400V.dat'
dataLED = pau.process_abalone_data(filename=file_LED,nn=0,nplot=10,volts=avolt,sipmv=32,ledv='4')
# Out:
# /data/abalone/ABALONE_RampingUp/2021_09_09_T1019_ABALONE_18kV_SiPM2_32V_LED400V.dat Number of events 595253.0
# Total events number: 595253
# event n. 0 time to process: 0.00
# event n. 100000 time to process: 14.26
# event n. 200000 time to process: 28.50
# event n. 300000 time to process: 42.75
# event n. 400000 time to process: 56.99
# event n. 500000 time to process: 71.21

# %%
new_data, new_wf = pau.select_data(dataLED,filename=file_LED,entr_cut=200,max_cut=1,area_cut=(0,1e7),
                                   pos_cut=(500,550),rt_cut=0,events=20, save=1,volts=avolt,sipmv=32,ledv='4')
# Out:
# /data/abalone/ABALONE_RampingUp/2021_09_09_T1019_ABALONE_18kV_SiPM2_32V_LED400V.dat Number of events 595253.0
# n. events 0 waveform samples 1024
# Events rejected by areaup 0 -> 0.0 %
#
# n. events 4359 waveform samples 1024
# Events rejected by areadown 4359 -> 0.7322936633666693 %
#
# n. events 0 waveform samples 1024
# Events rejected by entropy 0 -> 0.0 %
#
# n. events 0 waveform samples 1024
# Events rejected by max 0 -> 0.0 %
#
# n. events 4 waveform samples 1024
# Events rejected by risetime 4 -> 0.0006719831735413345 %
#
# n. events 46486 waveform samples 1024
# Events rejected by max position 46486 -> 7.809452451310619 %
#
# n. events 535130 waveform samples 1024
# Events selected  535130 -> 89.89958891429359 %

# %%
pau.plot_pe_spectrum(new_data['area'], volts=avolt, low=0, high=150, bins=300, ledv=4)
