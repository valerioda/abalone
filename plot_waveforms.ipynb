# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import quad
import scipy.special as sc
from scipy.integrate import odeint

# %%
def plotwf(filename, events = 10, samples = 1024):
    data = np.fromfile(filename,  dtype=np.int16)
    n = len(data)/samples
    print(filename,'Number of events',n)
    data = np.array(np.array_split(np.array(data),n))
    
    # plot of waveforms
    plt.figure(figsize=(12,6))
    for i in range(events):
        plt.plot(data[i][:])
    #plt.plot(X[0,:], c='r', label='SiPM - LED waveform')
    plt.xlabel('samples')
    plt.ylabel('channels')
    #plt.legend()

# %%
plotwf(f'data/SiPM1_25_5.dat')
# Out:
# data/SiPM1_25_5.dat Number of events 305029.0

# %%
plotwf('data/SiPM1_26_0.dat')
# Out:
# data/SiPM1_26_0.dat Number of events 300628.0

# %%
plotwf('data/SiPM1_27_0.dat')
# Out:
# data/SiPM1_27_0.dat Number of events 302216.0

# %%
plotwf('data/SiPM1_28_0.dat')
# Out:
# data/SiPM1_28_0.dat Number of events 299992.0

# %%
plotwf('data/SiPM1_29_0.dat')
# Out:
# data/SiPM1_29_0.dat Number of events 299022.0

# %%
plotwf('data/SiPM1_29_5.dat')
# Out:
# data/SiPM1_29_5.dat Number of events 299065.0
