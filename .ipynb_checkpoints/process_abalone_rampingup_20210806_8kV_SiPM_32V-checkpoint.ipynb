# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.integrate import quad
import scipy.special as sc
from scipy.integrate import odeint
import utility as psu
import scipy.integrate as integ
from scipy.optimize import curve_fit
from scipy import stats
import time
from matplotlib.colors import LogNorm
from numpy.random import randn
import matplotlib.colors as colors
import matplotlib.cbook as cbook
from matplotlib import cm
import os
import process_abalone_utility as pau

# %%
file_LED = '/data/abalone/ABALONE_RampingUp/2021_08_06_T1219_ABALONE_8kV_SiPM2_32V_LED400V.dat'
dataLED = pau.process_abalone_data(filename=file_LED,nn=0,nplot=10,w=10)
# Out:
# /data/abalone/ABALONE_RampingUp/2021_08_06_T1219_ABALONE_8kV_SiPM2_32V_LED400V.dat Number of events 593901.0
# Total events number: 593901
# event n. 0 time to process: 0.00
# event n. 100000 time to process: 14.91
# event n. 200000 time to process: 29.78
# event n. 300000 time to process: 44.74
# event n. 400000 time to process: 59.78
# event n. 500000 time to process: 75.08

# %%
avolt = 8
pau.plot_data(data=dataLED,fvolt=avolt,low=-1, high=4,low_max=0.5,high_max=4,low_en=1, high_en=100,
              low_fom=0.6,high_fom=1,high_rt=30)

# %%
new_data, new_wf = pau.select_data(dataLED,filename=file_LED,fvolt=avolt,entr_cut=200,
                                  max_cut=1,area_cut=(0,1e7), pos_cut=(500,550),rt_cut=0,events=20)
# Out:
# /data/abalone/ABALONE_RampingUp/2021_08_06_T1219_ABALONE_8kV_SiPM2_32V_LED400V.dat Number of events 593901.0
# n. events 0 waveform samples 1024
# Events rejected by areaup 0 -> 0.0 %
#
# n. events 45959 waveform samples 1024
# Events rejected by areadown 45959 -> 7.7384951363947865 %
#
# n. events 0 waveform samples 1024
# Events rejected by entropy 0 -> 0.0 %
#
# n. events 0 waveform samples 1024
# Events rejected by max 0 -> 0.0 %
#
# n. events 82 waveform samples 1024
# Events rejected by risetime 82 -> 0.013807014973876116 %
#
# n. events 233354 waveform samples 1024
# Events rejected by max position 233354 -> 39.29173380748644 %
#
# n. events 269661 waveform samples 1024
# Events selected  269661 -> 45.40504225451717 %

# %%
pau.plot_data(data=new_data,fvolt=avolt,low=0.1, high=3,low_max=0.5,high_max=4,low_en=2, high_en=5,
          low_fom=0.75,high_fom=1)

# %%
wf2 = new_wf[(new_data['area']>10)&(new_data['area']<20)]
psu.plot_waveforms( wf2,events=20,tlim=(4.5,7.5))
# Out:
# n. events 71517 waveform samples 1024

# %%
pau.plot_pe_spectrum(new_data['area'], volts=avolt, low=0, high=100, bins=300, ledv=4)

# %%
peakint = pau.calculate_integrals( new_wf, nn=0, volts=avolt, sipmv = 32, ledv = '4', plot = 0, save = 1 )
# Out:
# Total events: 269661
# event n. 0 area: 35.15, time to process: 0.01
# event n. 1000 area: 13.23, time to process: 5.81
# event n. 2000 area: 15.09, time to process: 11.70
# event n. 3000 area: 17.24, time to process: 17.45
# event n. 4000 area: 50.04, time to process: 23.34
# event n. 5000 area: 75.70, time to process: 29.24
# event n. 6000 area: 81.88, time to process: 35.16
# event n. 7000 area: 4.71, time to process: 40.98
# event n. 255000 area: 20.73, time to process: 1486.94
# event n. 256000 area: 45.80, time to process: 1492.62
# event n. 257000 area: 17.04, time to process: 1498.11
# event n. 258000 area: 24.22, time to process: 1503.66
# event n. 259000 area: 28.18, time to process: 1509.22
# event n. 260000 area: 66.23, time to process: 1514.97
# event n. 261000 area: 24.62, time to process: 1520.53
# event n. 262000 area: 50.00, time to process: 1526.03
# event n. 263000 area: 10.79, time to process: 1531.60
# event n. 264000 area: 36.53, time to process: 1537.22
# event n. 265000 area: 54.11, time to process: 1542.96
# event n. 266000 area: 24.51, time to process: 1548.45
# event n. 267000 area: 11.64, time to process: 1553.94
# event n. 268000 area: 24.05, time to process: 1559.45
# event n. 269000 area: 47.17, time to process: 1564.78

# %%
pau.plot_pe_spectrum(peakint, volts=avolt, low=0, high=100, bins=300, ledv=4)

# %%
file_LED2 = '/data/abalone/ABALONE_RampingUp/2021_08_06_T1230_ABALONE_8kV_SiPM2_32V_LED500V.dat'
dataLED2 = pau.process_abalone_data(filename=file_LED2,nn=0,nplot=10,w=10)
# Out:
# /data/abalone/ABALONE_RampingUp/2021_08_06_T1230_ABALONE_8kV_SiPM2_32V_LED500V.dat Number of events 594349.0
# Total events number: 594349
# event n. 0 time to process: 0.00
# event n. 100000 time to process: 14.62
# event n. 200000 time to process: 29.23
# event n. 300000 time to process: 43.84
# event n. 400000 time to process: 58.41
# event n. 500000 time to process: 73.10

# %%
pau.plot_data(data=dataLED2,fvolt=avolt,low=-1, high=4,low_max=0.5,high_max=4,low_en=1, high_en=100,
              low_fom=0.6,high_fom=1,high_rt=30)

# %%
new_data2, new_wf2 = pau.select_data(dataLED2,filename=file_LED2,fvolt=avolt,entr_cut=200,
                                  max_cut=1,area_cut=(0,1e7), pos_cut=(500,550),rt_cut=0,events=20)
# Out:
# /data/abalone/ABALONE_RampingUp/2021_08_06_T1230_ABALONE_8kV_SiPM2_32V_LED500V.dat Number of events 594349.0
# n. events 0 waveform samples 1024
# Events rejected by areaup 0 -> 0.0 %
#
# n. events 11424 waveform samples 1024
# Events rejected by areadown 11424 -> 1.9221030068192257 %
#
# n. events 0 waveform samples 1024
# Events rejected by entropy 0 -> 0.0 %
#
# n. events 0 waveform samples 1024
# Events rejected by max 0 -> 0.0 %
#
# n. events 18 waveform samples 1024
# Events rejected by risetime 18 -> 0.00302852364519836 %
#
# n. events 89181 waveform samples 1024
# Events rejected by max position 89181 -> 15.004820400135275 %
#
# n. events 420039 waveform samples 1024
# Events selected  420039 -> 70.67211352252633 %

# %%
pau.plot_data(data=new_data2,fvolt=avolt,low=0.1, high=3,low_max=0.5,high_max=4,low_en=2, high_en=5,
          low_fom=0.75,high_fom=1)

# %%
wf2 = new_wf2[(new_data2['area']>10)&(new_data2['area']<20)]
psu.plot_waveforms( wf2,events=20,tlim=(4.5,7.5))
# Out:
# n. events 72090 waveform samples 1024

# %%
pau.plot_pe_spectrum(new_data2['area'], volts=avolt, low=0, high=100, bins=300, ledv=5)
