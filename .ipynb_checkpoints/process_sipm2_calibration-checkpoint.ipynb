# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.integrate import quad
import scipy.special as sc
from scipy.integrate import odeint
import process_utility as psu
import scipy.integrate as integ
from scipy.optimize import curve_fit
from scipy.signal import find_peaks
import time

# %%
def process_pe_spectrum(nsipm, v, firstpe, lastpe, maxarea, bins, hlim, xlim, ylim):
    v_int = int(v)
    v_frac = int((v-v_int)*10)
    peakint = np.load(f'SiPM{nsipm}/peakint_SiPM{nsipm}_{v_int}_{v_frac}_LED2p75.npy')
    print('SiPM1 with',v_int+v_frac/10,' V, Number of values:',len(peakint[peakint>0]))
    pe, pe_err = psu.spectrum_fit(peakint,nsipm, v,1,maxarea,bins,hlim,firstpe,lastpe,plot=True)
    par, par_err = psu.fit_pe(pe,pe_err,nsipm, v,firstpe,xlim,ylim,offset=1)
    return par, par_err

# %%
par = []
par_err = []
voltages = np.arange(30,34.1,0.5)
nsipm = 2
first_pe = [8,5,4,4,3,2,2,2]
last_pe = [9,9,9,10,10,10,11,11]
area_lim = [10,10,12,13,15,17,21,23]
for i in range(7):
    p, p_err = process_pe_spectrum(nsipm,voltages[i], first_pe[i],
                                   last_pe[i],area_lim[i], 800, 70, 11, 0.05)
    par.append(p),par_err.append(p_err)
# Out:
# /home/valerio/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in greater
#   """
# /home/valerio/miniconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /home/valerio/miniconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# /home/valerio/miniconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:808: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /home/valerio/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in greater
#   """
# /home/valerio/miniconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /home/valerio/miniconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# SiPM1 with 30.0  V, Number of values: 53989
# PE 8 at 3.81 +/- 0.02 ADC x us
# PE 9 at 4.25 +/- 0.01 ADC x us
# SiPM1 with 30.5  V, Number of values: 102039
# PE 5 at 3.68 +/- 0.00 ADC x us
# PE 6 at 4.38 +/- 0.00 ADC x us
# PE 7 at 5.06 +/- 0.01 ADC x us
# PE 8 at 5.76 +/- 0.01 ADC x us
# /home/valerio/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in greater
#   """
# /home/valerio/miniconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /home/valerio/miniconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# /home/valerio/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in greater
#   """
# /home/valerio/miniconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /home/valerio/miniconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# SiPM1 with 31.0  V, Number of values: 150473
# PE 4 at 3.39 +/- 0.01 ADC x us
# PE 5 at 4.18 +/- 0.01 ADC x us
# PE 6 at 5.00 +/- 0.00 ADC x us
# PE 7 at 5.84 +/- 0.01 ADC x us
# PE 8 at 6.65 +/- 0.01 ADC x us
# PE 9 at 7.50 +/- 0.01 ADC x us
# SiPM1 with 31.5  V, Number of values: 179765
# PE 4 at 3.70 +/- 0.01 ADC x us
# PE 5 at 4.69 +/- 0.01 ADC x us
# PE 6 at 5.65 +/- 0.00 ADC x us
# PE 7 at 6.61 +/- 0.01 ADC x us
# PE 8 at 7.58 +/- 0.01 ADC x us
# PE 9 at 8.58 +/- 0.01 ADC x us
# PE 10 at 9.54 +/- 0.01 ADC x us
# SiPM1 with 32.0  V, Number of values: 213458
# PE 3 at 4.09 +/- 0.01 ADC x us
# PE 4 at 5.20 +/- 0.01 ADC x us
# PE 5 at 6.33 +/- 0.01 ADC x us
# PE 6 at 7.43 +/- 0.01 ADC x us
# PE 7 at 8.54 +/- 0.00 ADC x us
# PE 8 at 9.67 +/- 0.01 ADC x us
# PE 9 at 10.77 +/- 0.02 ADC x us
# /home/valerio/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in greater
#   """
# /home/valerio/miniconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /home/valerio/miniconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# /home/valerio/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in greater
#   """
# /home/valerio/miniconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /home/valerio/miniconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# PE 10 at 11.88 +/- 0.02 ADC x us
# SiPM1 with 32.5  V, Number of values: 227378
# PE 2 at 3.26 +/- 0.01 ADC x us
# PE 3 at 4.50 +/- 0.01 ADC x us
# PE 4 at 5.74 +/- 0.00 ADC x us
# PE 5 at 7.00 +/- 0.00 ADC x us
# PE 6 at 8.25 +/- 0.01 ADC x us
# PE 7 at 9.49 +/- 0.01 ADC x us
# PE 8 at 10.77 +/- 0.01 ADC x us
# PE 9 at 12.03 +/- 0.01 ADC x us
# PE 10 at 13.27 +/- 0.01 ADC x us
# SiPM1 with 33.0  V, Number of values: 242997
# PE 2 at 3.45 +/- 0.02 ADC x us
# PE 3 at 4.81 +/- 0.01 ADC x us
# PE 4 at 6.16 +/- 0.01 ADC x us
# PE 5 at 7.52 +/- 0.01 ADC x us
# PE 6 at 8.85 +/- 0.01 ADC x us
# PE 7 at 10.25 +/- 0.01 ADC x us
# PE 8 at 11.62 +/- 0.01 ADC x us
# PE 9 at 12.97 +/- 0.01 ADC x us
# PE 10 at 14.28 +/- 0.02 ADC x us
# /home/valerio/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in greater
#   """
# /home/valerio/miniconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /home/valerio/miniconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# PE 11 at 15.56 +/- 0.03 ADC x us
# /home/valerio/repository/abalone/process_utility.py:418: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(12,6))

# %%
plt.figure(figsize=(12,6))
x = range(0,12)
for i in range(len(par)):
    plt.plot(x,psu.retta(x,par[i][0],par[i][1]),label=f'SiPM at {voltages[i]} V')
plt.ylabel(r'area ($ADC\times \mu$s)',ha='right',y=1,fontsize=14)
plt.xlabel('PE number',ha='right',x=1,size=40,fontsize=14)
plt.legend(fontsize=14)
