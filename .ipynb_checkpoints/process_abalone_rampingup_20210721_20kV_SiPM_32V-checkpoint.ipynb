# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.integrate import quad
import scipy.special as sc
from scipy.integrate import odeint
import utility as psu
import scipy.integrate as integ
from scipy.optimize import curve_fit
from scipy import stats
import time
from matplotlib.colors import LogNorm
from numpy.random import randn
import matplotlib.colors as colors
import matplotlib.cbook as cbook
from matplotlib import cm
import os
import process_abalone_utility as pau

# %%
file_LED299 = '/data/abalone/ABALONE_RampingUp/2021_07_27_T1023_ABALONE_20kV_SiPM2_30V_LED3V.dat'
dataLED = pau.process_abalone_data(filename=file_LED299,nn=0,nplot=10,w=10)
# Out:
# /data/abalone/ABALONE_RampingUp/2021_07_27_T1023_ABALONE_20kV_SiPM2_30V_LED3V.dat Number of events 595399.0
# Total events number: 595399
# event n. 0 time to process: 0.00
# event n. 100000 time to process: 12.12
# event n. 200000 time to process: 24.17
# event n. 300000 time to process: 36.45
# event n. 400000 time to process: 48.53
# event n. 500000 time to process: 60.70

# %%
pau.plot_data(data=dataLED,fvolt=18,low=-1, high=4,low_max=0.5,high_max=4,low_en=1, high_en=100,
              low_fom=0.6,high_fom=1,high_rt=30)

# %%
new_data, new_wf = pau.select_data(dataLED,filename=file_LED299,fvolt=18,entr_cut=200,
                                  max_cut=1,area_cut=(0,1e7), pos_cut=(500,550),rt_cut=0,events=20)
# Out:
# /data/abalone/ABALONE_RampingUp/2021_07_27_T1023_ABALONE_20kV_SiPM2_30V_LED3V.dat Number of events 595399.0
# n. events 0 waveform samples 1024
# Events rejected by areaup 0 -> 0.0 %
#
# n. events 109099 waveform samples 1024
# Events rejected by areadown 109099 -> 18.323678743162148 %
#
# n. events 0 waveform samples 1024
# Events rejected by entropy 0 -> 0.0 %
#
# n. events 0 waveform samples 1024
# Events rejected by max 0 -> 0.0 %
#
# n. events 43 waveform samples 1024
# Events rejected by risetime 43 -> 0.007222047736055989 %
#
# n. events 412057 waveform samples 1024
# Events rejected by max position 412057 -> 69.2068679994424 %
#
# n. events 159857 waveform samples 1024
# Events selected  159857 -> 26.848718254481447 %

# %%
pau.plot_data(data=new_data,fvolt=18,low=0.1, high=2.1,low_max=0.5,high_max=3,low_en=2.3, high_en=3.5,
          low_fom=0.75,high_fom=1)

# %%
wf2 = new_wf[(new_data['area']>20)&(new_data['area']<30)]
psu.plot_waveforms( wf2,events=20,tlim=(4.5,7.5))
# Out:
# n. events 57199 waveform samples 1024

# %%
popt = pau.fit_pe_spectrum(new_data['area'], volts = 20, low = 11, high = 80, bins = 300)

# %%
popt[1]/0.487
# Out:
# 43.80106503033046

# %%
#peakint = np.load('peakint_SiPM1_27_5_LED2p75.npy')
peakint = pau.calculate_integrals( new_wf, nn = 10000 )
# Out:
# Total events: 10000
# event n. 0 area: 72.94, time to process: 0.01
# event n. 1000 area: 25.74, time to process: 3.86
# event n. 2000 area: 24.43, time to process: 7.87
# event n. 3000 area: 24.45, time to process: 11.91
# event n. 4000 area: 22.73, time to process: 15.79
# event n. 5000 area: 24.87, time to process: 19.87
# event n. 6000 area: 23.63, time to process: 23.86
# event n. 7000 area: 36.02, time to process: 27.72
# event n. 8000 area: 23.10, time to process: 31.66
# event n. 9000 area: nan, time to process: 35.52

# %%
popt = pau.fit_pe_spectrum(peakint, volts = 20, low = 0, high = 80, bins = 300)

# %%
popt[1]/0.487
# Out:
# 45.25888822411319
