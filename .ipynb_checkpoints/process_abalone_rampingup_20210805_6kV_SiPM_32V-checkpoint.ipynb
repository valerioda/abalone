# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.integrate import quad
import scipy.special as sc
from scipy.integrate import odeint
import utility as psu
import scipy.integrate as integ
from scipy.optimize import curve_fit
from scipy import stats
import time
from matplotlib.colors import LogNorm
from numpy.random import randn
import matplotlib.colors as colors
import matplotlib.cbook as cbook
from matplotlib import cm
import os
import process_abalone_utility as pau

# %%
file_LED = '/data/abalone/ABALONE_RampingUp/2021_08_05_T1426_ABALONE_6kV_SiPM2_32V_LED500V.dat'
dataLED = pau.process_abalone_data(filename=file_LED,nn=0,nplot=10,w=10)
# Out:
# /data/abalone/ABALONE_RampingUp/2021_08_05_T1426_ABALONE_6kV_SiPM2_32V_LED500V.dat Number of events 595419.0
# Total events number: 595419
# event n. 0 time to process: 0.02
# event n. 100000 time to process: 12.52
# event n. 200000 time to process: 24.97
# event n. 300000 time to process: 37.94
# event n. 400000 time to process: 50.78
# event n. 500000 time to process: 63.68

# %%
avolt = 6
pau.plot_data(data=dataLED,fvolt=avolt,low=-1, high=4,low_max=0.5,high_max=4,low_en=1, high_en=100,
              low_fom=0.6,high_fom=1,high_rt=30)

# %%
new_data, new_wf = pau.select_data(dataLED,filename=file_LED,fvolt=avolt,entr_cut=200,
                                  max_cut=1,area_cut=(0,1e7), pos_cut=(500,550),rt_cut=0,events=20)
# Out:
# /data/abalone/ABALONE_RampingUp/2021_08_05_T1426_ABALONE_6kV_SiPM2_32V_LED500V.dat Number of events 595419.0
# n. events 0 waveform samples 1024
# Events rejected by areaup 0 -> 0.0 %
#
# n. events 42280 waveform samples 1024
# Events rejected by areadown 42280 -> 7.10088189997296 %
#
# n. events 0 waveform samples 1024
# Events rejected by entropy 0 -> 0.0 %
#
# n. events 0 waveform samples 1024
# Events rejected by max 0 -> 0.0 %
#
# n. events 42 waveform samples 1024
# Events rejected by risetime 42 -> 0.00705385619202612 %
#
# n. events 195483 waveform samples 1024
# Events rejected by max position 195483 -> 32.831165952043854 %
#
# n. events 279787 waveform samples 1024
# Events selected  279787 -> 46.989934819009804 %

# %%
pau.plot_data(data=new_data,fvolt=avolt,low=0.1, high=3,low_max=0.5,high_max=4,low_en=2, high_en=5,
          low_fom=0.75,high_fom=1)

# %%
wf2 = new_wf[(new_data['area']>10)&(new_data['area']<20)]
psu.plot_waveforms( wf2,events=20,tlim=(4.5,7.5))
# Out:
# n. events 74217 waveform samples 1024

# %%
pau.plot_pe_spectrum(new_data['area'], volts=avolt, low=0, high=100, bins=300, ledv=5)

# %%
popt[1]/1.113
# Out:
# 18.972911326349546

# %%
#peakint = pau.calculate_integrals( new_wf, nn=0, volts=avolt, sipmv = 32, ledv = '4p0', plot = 0, save = 1 )

# %%
#popt = pau.fit_pe_spectrum(peakint, volts=avolt, low=0, high = 250, bins=300, fit_range=(30,120),dpe=1)

# %%
popt[1]/1.113
# Out:
# 15.86322840496608

# %%
file_LED2 = '/data/abalone/ABALONE_RampingUp/2021_08_05_T1439_ABALONE_6kV_SiPM2_32V_LED700V.dat'
dataLED2 = pau.process_abalone_data(filename=file_LED2,nn=0,nplot=10,w=10)
# Out:
# /data/abalone/ABALONE_RampingUp/2021_08_05_T1439_ABALONE_6kV_SiPM2_32V_LED700V.dat Number of events 595510.0
# Total events number: 595510
# event n. 0 time to process: 0.00
# event n. 100000 time to process: 14.04
# event n. 200000 time to process: 28.35
# event n. 300000 time to process: 42.67
# event n. 400000 time to process: 56.87
# event n. 500000 time to process: 71.19

# %%
pau.plot_data(data=dataLED2,fvolt=avolt,low=-1, high=4,low_max=0.5,high_max=4,low_en=1, high_en=100,
              low_fom=0.6,high_fom=1,high_rt=30)

# %%
new_data2, new_wf2 = pau.select_data(dataLED2,filename=file_LED2,fvolt=avolt,entr_cut=200,
                                  max_cut=1,area_cut=(0,1e7), pos_cut=(500,550),rt_cut=0,events=20)
# Out:
# /data/abalone/ABALONE_RampingUp/2021_08_05_T1439_ABALONE_6kV_SiPM2_32V_LED700V.dat Number of events 595510.0
# n. events 0 waveform samples 1024
# Events rejected by areaup 0 -> 0.0 %
#
# n. events 7624 waveform samples 1024
# Events rejected by areadown 7624 -> 1.280247183086766 %
#
# n. events 0 waveform samples 1024
# Events rejected by entropy 0 -> 0.0 %
#
# n. events 0 waveform samples 1024
# Events rejected by max 0 -> 0.0 %
#
# n. events 2 waveform samples 1024
# Events rejected by risetime 2 -> 0.00033584658527984417 %
#
# n. events 63244 waveform samples 1024
# Events rejected by max position 63244 -> 10.620140719719231 %
#
# n. events 422326 waveform samples 1024
# Events selected  422326 -> 70.91837248744774 %

# %%
pau.plot_data(data=new_data2,fvolt=avolt,low=0.1, high=3,low_max=0.5,high_max=4,low_en=2, high_en=5,
          low_fom=0.75,high_fom=1)

# %%
wf2 = new_wf2[(new_data2['area']>10)&(new_data2['area']<20)]
psu.plot_waveforms( wf2,events=20,tlim=(4.5,7.5))
# Out:
# n. events 31608 waveform samples 1024

# %%
pau.plot_pe_spectrum(new_data['area'], volts=avolt, low=0, high=100, bins=300, ledv=7)
