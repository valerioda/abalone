# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.integrate import quad
import scipy.special as sc
from scipy.integrate import odeint
import utility as psu
import scipy.integrate as integ
from scipy.optimize import curve_fit
from scipy import stats
import time
from matplotlib.colors import LogNorm
from numpy.random import randn
import matplotlib.colors as colors
import matplotlib.cbook as cbook
from matplotlib import cm
import os
import process_abalone_utility as pau

# %%
file_LED = '/data/abalone/ABALONE_RampingUp/2021_07_20_T1622_ABALONE_19kV_SiPM2_30V_LED299V.dat'
dataLED = pau.process_abalone_data(filename=file_LED,nn=0,nplot=10,w=10)
# Out:
# /data/abalone/ABALONE_RampingUp/2021_07_20_T1622_ABALONE_19kV_SiPM2_30V_LED299V.dat Number of events 592420.0
# Total events number: 592420
# event n. 0 time to process: 0.00
# event n. 100000 time to process: 11.62
# event n. 200000 time to process: 23.21
# event n. 300000 time to process: 34.85
# event n. 400000 time to process: 46.43
# event n. 500000 time to process: 58.00

# %%
pau.plot_data(data=dataLED,fvolt=18,low=-1, high=4,low_max=0.5,high_max=4,low_en=1, high_en=100,
              low_fom=0.6,high_fom=1,high_rt=30)

# %%
new_data, new_wf = pau.select_data(dataLED,filename=file_LED,fvolt=18,entr_cut=200,
                                  max_cut=1,area_cut=(0,1e7), pos_cut=(500,550),rt_cut=0,events=20)
# Out:
# /data/abalone/ABALONE_RampingUp/2021_07_20_T1622_ABALONE_19kV_SiPM2_30V_LED299V.dat Number of events 592420.0
# n. events 0 waveform samples 1024
# Events rejected by areaup 0 -> 0.0 %
#
# n. events 90297 waveform samples 1024
# Events rejected by areadown 90297 -> 15.242057999392323 %
#
# n. events 0 waveform samples 1024
# Events rejected by entropy 0 -> 0.0 %
#
# n. events 0 waveform samples 1024
# Events rejected by max 0 -> 0.0 %
#
# n. events 65 waveform samples 1024
# Events rejected by risetime 65 -> 0.010971945579149928 %
#
# n. events 422989 waveform samples 1024
# Events rejected by max position 422989 -> 71.40018905506228 %
#
# n. events 146959 waveform samples 1024
# Events selected  146959 -> 24.80655615948145 %

# %%
pau.plot_data(data=new_data,fvolt=18,low=0.1, high=2.1,low_max=0.5,high_max=3,low_en=2.3, high_en=3.5,
             low_fom=0.75,high_fom=1)

# %%
wf2 = new_wf[(new_data['area']>0)&(new_data['area']<10)]
psu.plot_waveforms( wf2,events=20,tlim=(4.5,7.5))
plt.axvline(5.2)
plt.axvline(6.2)
plt.axvline(7.2)
plt.axhline(14765)
# Out:
# n. events 29891 waveform samples 1024

# %%
popt = pau.fit_pe_spectrum(new_data['area'], volts = 19, low = 0, high = 80, bins = 300, fit_range=(15,70))

# %%
popt[1]/0.440
# Out:
# 50.4189429836154

# %%
peakint = np.load('processed_data/peakint_ABALONE_19kV_SiPM2_30V.npy')
#peakint = pau.calculate_integrals( new_wf, nn = 0, volts = 19, save = 1)

# %%
popt = pau.fit_pe_spectrum(peakint, volts = 19, low = 0, high = 80, bins = 300, fit_range = (15,70) )

# %%
popt[1]/0.440
# Out:
# 51.310479038152096
